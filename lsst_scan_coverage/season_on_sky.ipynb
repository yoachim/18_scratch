# %%
import numpy as np
import healpy as hp
import  lsst.sims.featureScheduler as fs
from lsst.sims.utils import _approx_RaDec2AltAz, Site, hpid2RaDec, m5_flat_sed

# %%
nside = 32
hpids = np.arange(hp.nside2npix(nside))

# %%
ra,dec = hpid2RaDec(nside, hpids)

# %%
hp.mollview(ra)

# %%
# Let's say the sun starts at RA 60 degrees
effective_night = ra - 60
effective_night[np.where(effective_night < 0)] += 360
effective_night = effective_night/360*365.25 #- 365.25

# %%
hp.mollview(effective_night)

# %%
# OK, I want the thing 180 degrees away from 60 to be -180? at 60 degrees is starting it's first full season.

# %%
night = 20
season = np.floor((effective_night + night)/365.25)

hp.mollview(season)
