# %%
# %matplotlib inline
import lsst.sims.skybrightness_pre as sb
import healpy as hp
import numpy as np

# %%
sm = sb.SkyModelPre(preload=False)

# %%
mjd = 60050.314212963
ack = sm.returnMags(mjd)

# %%
hp.mollview(ack['u'], title="%f"%mjd, unit='u sky (mag/sq arcsec)')

# %%
mjd = 60050.1853472222
ack = sm.returnMags(mjd)
