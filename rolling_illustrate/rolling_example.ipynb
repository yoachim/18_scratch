# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles

# %%
dbFile = 'baseline_test10yrs.db'
# This connection checks which version it thinks the database is and should do the right thing schema-wise
conn = db.Database(dbFile, defaultTable='observations')
outDir='temp'
resultsDb = db.ResultsDb(outDir=outDir)

# %%
sqls = ['filter="r" and night < 365',
        'filter="r" and night > 365 and night < 730',
        'filter="r" and night < 730']

bundleList = []
plotDict = {'percentileClip': 95.}
        
for sql in sqls:
    metric = metrics.CountMetric(col='mjd')
    slicer = slicers.HealpixSlicer(latCol='dec', lonCol='RA')
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict, runName='Baseline-ish'))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
# Out:
# Querying database observations with constraint filter="r" and night < 730 for columns ['mjd', 'dec', 'RA']
# Found 91361 visits
# Running:  ['Baseline-ish_Count_mjd_r_and_night_lt_730_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint filter="r" and night < 365 for columns ['mjd', 'dec', 'RA']
# Found 35513 visits
# Running:  ['Baseline-ish_Count_mjd_r_and_night_lt_365_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint filter="r" and night > 365 and night < 730 for columns ['mjd', 'dec', 'RA']
# Found 55808 visits
# Running:  ['Baseline-ish_Count_mjd_r_and_night_gt_365_and_night_lt_730_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.

# %%
bg.plotAll(closefigs=False)
# Out:
# Plotting figures with "filter="r" and night < 730" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 1632 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 30.3779  dipole: lon: -9.56967, lat: -50.2713, amp: 8.97636
# Plotting complete.
# Plotting figures with "filter="r" and night < 365" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 2111 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 12.666  dipole: lon: -23.3464, lat: -43.5029, amp: 5.12614
# Plotting complete.
# Plotting figures with "filter="r" and night > 365 and night < 730" constraint now.
# ...

# %%
dbFile = 'rolling_10yrs.db'
# This connection checks which version it thinks the database is and should do the right thing schema-wise
conn = db.Database(dbFile, defaultTable='observations')
outDir='temp2'
resultsDb = db.ResultsDb(outDir=outDir)

# %%
sqls = ['filter="r" and night < 365',
        'filter="r" and night > 365 and night < 730',
        'filter="r" and night < 730']

bundleList = []
plotDict = {'percentileClip': 95.}
        
for sql in sqls:
    metric = metrics.CountMetric(col='mjd')
    slicer = slicers.HealpixSlicer(latCol='dec', lonCol='RA')
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict, runName='Rolling'))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
bg.plotAll(closefigs=False)
# Out:
# Querying database observations with constraint filter="r" and night < 730 for columns ['mjd', 'dec', 'RA']
