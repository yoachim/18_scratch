# %%
import matplotlib.pylab as plt
# %matplotlib inline
import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles

# %%
obsfile = '/Users/yoachim/gitRepos/sims_movingObjects/examples/baseline2018a_neos_100_full_obs.txt'
orbitfile = '/Users/yoachim/gitRepos/sims_movingObjects/examples/neos_100.s3m'
slicer = slicers.MoObjSlicer()
slicer.setupSlicer(orbitfile)
slicer.readObs(obsfile)
metric = metrics.NObsMetric(snrLimit=1.)
bundle = metricBundles.MoMetricBundle(metric, slicer)

# %%
mmbg = metricBundles.MoMetricBundleGroup({1: bundle})

# %%
mmbg.runAll()
# Out:
# Running metrics [1]
# Calculated and saved all metrics.

# %%
mmbg.plotAll(closefigs=False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-902754b6211b> in <module>()
# ----> 1 mmbg.plotAll(closefigs=False)
#
# ~/gitRepos/sims_maf/python/lsst/sims/maf/metricBundles/moMetricBundle.py in plotAll(self, savefig, outfileSuffix, figformat, dpi, thumbnail, closefigs)
#     448         for b in self.bundleDict.values():
#     449             try:
# --> 450                 b.plot(plotHandler=plotHandler, outfileSuffix=outfileSuffix, savefig=savefig)
#     451             except ValueError as ve:
#     452                 message = 'Plotting failed for metricBundle %s.' % (b.fileRoot)
#
# ~/gitRepos/sims_maf/python/lsst/sims/maf/metricBundles/metricBundle.py in plot(self, plotHandler, plotFunc, outfileSuffix, savefig)
#     610         else:
#     611             for plotFunc in self.plotFuncs:
# ...
