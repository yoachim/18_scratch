# %%
import healpy as hp
import numpy as np
import lsst.sims.utils as utils
import matplotlib.pylab as plt
# %matplotlib inline

# %%
nside = 32
hpid = np.arange(hp.nside2npix(nside))

# %%
ra,dec = utils.hpid2RaDec(nside, hpid)

# %%
hp.mollview(ra)

# %%
alt, az = utils.approx_RaDec2AltAz(ra, dec, -30., 0., 0., lmst=0.)

# %%
hp.mollview(alt)

# %%
obs = utils.ObservationMetaData(mjd=56984)

# %%
alt,az,pa = utils.altAzPaFromRaDec(ra, dec, obs, includeRefraction=False)

# %%
hp.mollview(pa)

# %%
hp.mollview(az)
